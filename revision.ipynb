# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhi-S-Thakur/EDA-RealEstate/blob/main/revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def double(x:
           return x*x)

# %%
print(
    list(map(
        lambda x:[i**2 for i in x],[[1,2,3],[3,4,5]]
    ))
)
# Out:
# [[1, 4, 9], [9, 16, 25]]

# %%
from functools import reduce
list(filter(lambda x:int(x)%2 == 0 if x!="0" else False,"0123456789" ))
# Out:
# ['2', '4', '6', '8']

# %%
reduce(lambda x,y:x+y,(1,2,3,4))
# Out:
# 10

# %%
dict(
    map(
        lambda x:
         (x[0]**2,x[1]**2) if x[0]==x[0] else (x[0],x[0]),{1:2,2:2,}.items()))
# Out:
# {1: 4, 4: 4}

# %% [markdown]
# # Nullified

# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhi-S-Thakur/EDA-RealEstate/blob/main/LearningSVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df = pd.read_csv("/content/logistic_regression_1000 (1).csv")

# %%
df.head()
# Out:
#    Study_Hours  Attendance  Pass_Fail
# 0     3.745401   51.107976          0
# 1     9.507143   72.514057          1
# 2     7.319939   92.376750          0
# 3     5.986585   83.933493          1
# 4     1.560186   88.393669          0

# %%
df.describe()
# Out:
#        Study_Hours   Attendance   Pass_Fail
# count  1000.000000  1000.000000  1000.00000
# mean      4.902566    70.421038     0.32000
# std       2.921374    17.531394     0.46671
# min       0.046320    40.193096     0.00000
# 25%       2.359733    54.464456     0.00000
# 50%       4.968074    71.124034     0.00000
# 75%       7.443196    85.627903     1.00000
# max       9.997177    99.964824     1.00000

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
model = {
    "Linear": SVC(kernel = "linear",C=1),
    "Poly": SVC(kernel = "poly",C=1, degree = 3),
    "RBF": SVC(kernel = "rbf",gamma = 0.1,C=1),
}

# %%
X = df.drop("Pass_Fail", axis = 1)
Y = df["Pass_Fail"]
X_train,X_test,y_train,y_test = train_test_split(X,Y,train_size = 0.8, random_state = 42)

# %%
sc = StandardScaler()

# %%
X_scal = sc.fit_transform(X_train)
X_scal_test = sc.fit_transform(X_test)

# %%
for name, model in model.items():
  model.fit(X_scal,y_train)
  print(f"{name} {model.score(X_scal_test, y_test)}")
# Out:
# Linear 0.775
# Poly 0.75
# RBF 0.77

# %%
input = sc.transform([[8,60]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
for name,model in models.items():
  print(name,*(model.predict(input)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2488054516.py in <cell line: 0>()
# ----> 1 for name,model in models.items():
#       2   print(name,*(model.predict(input)))
#
# NameError: name 'models' is not defined
